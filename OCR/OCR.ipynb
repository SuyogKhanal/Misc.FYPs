# %%
import easyocr
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
IMAGE_PATH = 'image.jpg'

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[1470, 181], [1714, 181], [1714, 245], [1470, 245]],
#   'CASTLECASTLECAS]',
#   0.9676637712503869),
#  ([[272, 830], [318, 830], [318, 862], [272, 862]], 'P2', 0.6375448998925652),
#  ([[345, 829], [401, 829], [401, 871], [345, 871]], 'SA', 0.9996292121640291),
#  ([[441, 833], [549, 833], [549, 871], [441, 871]],
#   '185-2',
#   0.9549178892395905),
#  ([[601, 837], [777, 837], [777, 873], [601, 873]],
#   'OVERS 29.1',
#   0.7645162913815622),
#  ([[863, 835], [997, 835], [997, 874], [863, 874]],
#   'ToSS SA',
#   0.3257390304422087),
#  ([[1068, 837], [1275, 837], [1275, 873], [1068, 873]],
#   'SPEED 79.0KPH',
#   0.7798790157846841),
#  ([[342, 888], [570, 888], [570, 920], [342, 920]],
#   'du PLESSIS 81 * (76)',
#   0.5725310152610936),
#  ([[646, 888], [870, 888], [870, 920], [646, 920]],
#   'de VILLIERS 46 (43)',
#   0.9768730454604908),
#  ([[1039, 887], [1280, 887], [1280, 923], [1039, 923]],
#   'GUNARATNE 0-9(1)',
#   0.9743242249965525),
#  ([[1417, 895], [1495, 895], [1495, 915], [1417, 915]],
#   'Stt Lankd',
#   0.34886218505227556),
#  ([[1033.1715728752538, 274.1715728752538],
#    [1273.7829064669306, 231.7001466765613],
#    [1278.8284271247462, 269.8284271247462],
#    [1039.2170935330694, 312.2998533234387]],
#   'CASTLECASTLECASTLE',
#   0.9512266964498081),
#  ([[658.0769230769231, 366.38461538461536],
#    [863.389477864572, 305.60573934659715],
#    [872.9230769230769, 351.61538461538464],
#    [667.610522135428, 412.39426065340285]],
#   'castlecastlecastle',
#   0.4842347469896411),
#  ([[397.16445884946233, 513.0703072118276],
#    [533.2861151901558, 422.2315192773443],
#    [553.8355411505377, 463.9296927881723],
#    [417.7138848098442, 554.7684807226557]],
#   'UFRECUSPRACMSTLE',
#   0.015295623665923097)]
